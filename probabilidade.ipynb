# %% [markdown]
# <a href="https://colab.research.google.com/github/01Trixie/Exerc-cio1_Threads/blob/master/probabilidade.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
dados = pd.read_csv('/content/drive/MyDrive/Faculdade/Estatística/pesquisa_tratada.csv',
                    sep=',', encoding='UTF-8')
dados.head(24)
# Out:
#                ra  altura cor_favorita  num_calcado
# 0   1110482212025    1.85        cinza           44
# 1   1110482212030    1.80      laranja           44
# 2   1110482212009    1.63     vermelho           39
# 3   1110482212036    1.56         azul           37
# 4   1110482222039    1.90         azul           42
# 5   1110482212004    1.83      laranja           40
# 6   1110482212026    1.64     vermelho           39
# 7   1110482212002    1.88     vermelho           42
# 8   1110482212035    1.85         roxo           44
# 9    111048212031    1.50      laranja           35
# 10  1110482212016    1.74        verde           35
# 11  1110482212001    1.70        preto           42
# 12  1110482212019    1.68       branco           37
# 13  1110482212018    1.64        cinza           36
# 14  1110482212024    1.65        preto           38
# 15  1110482212021    1.70        preto           41
# 16  1110482212039    1.84        preto           43
# ...

# %%
#isin - juntar nomes para buscar.
#loc para  localizar o item dentro da tabela.

cor_preta = dados.loc[dados.cor_favorita.isin(['preta', 'preto'])]
cor_preta.head()
# Out:
#                ra  altura cor_favorita  num_calcado
# 11  1110482212001    1.70        preto           42
# 14  1110482212024    1.65        preto           38
# 15  1110482212021    1.70        preto           41
# 16  1110482212039    1.84        preto           43
# 19  1110482212007    1.65        preto           40

# %%
altura1 = dados.loc[dados.altura < 1.70]
altura1.head(12)
# Out:
#                ra  altura cor_favorita  num_calcado
# 2   1110482212009    1.63     vermelho           39
# 3   1110482212036    1.56         azul           37
# 6   1110482212026    1.64     vermelho           39
# 9    111048212031    1.50      laranja           35
# 12  1110482212019    1.68       branco           37
# 13  1110482212018    1.64        cinza           36
# 14  1110482212024    1.65        preto           38
# 18  1110482212011    1.69         roxo           38
# 19  1110482212007    1.65        preto           40
# 20  1110482212022    1.55        preto           36
# 21  1110482212043    1.55        verde           35

# %%
#ver qtde de dados que tem
len(dados)
# Out:
# 22

# %%
len(cor_preta)
# Out:
# 6

# %%
len(altura1)
# Out:
# 11

# %%
#funcao -- def + nomeFunc + parâmetro (A, B) + :
#def cria a funcao
#.2f.format(variavel) -- mostrar duas virgulas após a vírgula.

def probab(A, E):
  resultado = (A / E)* 100
  print('{: .2f}'.format(resultado))

# %%
#probabilidade de retirar preferencia cor preta
probab(len(cor_preta), len(dados))
# Out:
#  27.27

# %%
#probabilidade de de ser menor que 1.70

probab(len(altura1),len(dados))
# Out:
#  50.00

# %%
#probab de não ocorrer um evento

def probab_nao(A, E):
  resultado = (1-(A/E))*100
  print('{: .2f}'.format(resultado))

# %%
cor_vermelha = dados.loc[dados.cor_favorita.isin(['vermelha', 'vermelho'])]
cor_vermelha.head()
# Out:
#               ra  altura cor_favorita  num_calcado
# 2  1110482212009    1.63     vermelho           39
# 6  1110482212026    1.64     vermelho           39
# 7  1110482212002    1.88     vermelho           42

# %%
probab_nao(len(cor_vermelha), len(dados))
# Out:
#  86.36

# %% [markdown]
# ## Probabilidade da Intersecção de dois eventos independentes.

# %%
#func da probabilidade da intersecção de dois eventos independentes
def probab_inter(A, B, E):
  resultado = (A/E * B/E)*100
  print('{: .1f}'.format(resultado))

# %%
#Probab de sortear duas pessoas sendo uma delas com a altura menor que 1,70
#E a outra cor favorita preta com reposição

probab_inter(len(cor_preta),len(altura1), len(dados))
# Out:
#  13.6

# %% [markdown]
# ##Probabilidade da União (AUB)

# %%
def probab_uniao(A, B, E):
  prob = (((A/E + B/E) - (A/E * B/E) / E) *100)
  print('{: .2f}'.format(prob))

# %%
probab_uniao(len(cor_preta), len(altura1), len(dados))
# Out:
#  76.65
